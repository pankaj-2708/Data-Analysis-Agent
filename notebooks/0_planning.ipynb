# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="qwen2.5-coder:3b")

# %%
# %%time
res=model.invoke('hi')
res.content
# Out:
# CPU times: total: 15.6 ms
# Wall time: 18.9 s
# "How's it going? Is there something I can help you with or would you like to chat?"

# %%
# %%time
for i in model.stream("tell me about ai in detail"):
    print(i.content,end=" ")
# Out:
# Art ificial  Intelligence  ( AI )  is  a  broad  and  rapidly  evolving  field  that  encompasses  the  development  of  algorithms ,  statistical  models ,  and  computer  systems  that  can  perform  tasks  typically  requiring  human  intelligence .  The  goal  of  AI  research  is  to  create  machines  that  can  think ,  learn ,  and  act  like  humans ,  or  even  surpass  human  capabilities  in  specific  areas .
#
#  ** History  of  AI : **
#
#  The  study  of  Artificial  Intelligence  began  in  the   195 0 s  with  the  Dart mouth  Summer  Research  Project  on  Artificial  Intelligence ,  led  by  John  McCarthy ,  Marvin  M insky ,  Nath aniel  Rochester ,  and  Claude  Shannon .  The  term  " Art ificial  Intelligence "  was  coined  during  this  project .  Since  then ,  AI  research  has  undergone  significant  advancements ,  driven  by  breakthrough s  in  computing  power ,  data  storage ,  and  algorithms .
#
#  ** Types  of  AI : **
#
# ...

# %% [markdown]
# ### User will give a csv file as input
#
#
# ### First node will have access to tools for reading csv file it will read and generate a detailed schema for them which will be used in next nodes
#
# ### After that there will be two parallel nodes one will generate a list of pandas query and one will generate a list of queries for graph visualisation
#
# ### Now n parallel nodes will be created from each of the above node each will execute a query and return the result
#
# ### A collector node which will collect output of all parallel nodes
#
# ### A node that will recieve all of the outputs and its work is to draft a markdown file as a report
#
#
# # Project Structure
#
# ## An mcp folder which has code for mcp server
#
# ## An utility folder which will contain all generated figures and csv files (currently later aws s3 will be used)

# %% [markdown]
# ## an update status that will tell which node is currently running
#
# ## stream workflow from bg to frontend
#
# ## new and better model
#
# ## full markdown file (with images) export to frontend
#
# ## integrate async postgrae sql check ptr
#
# # Problem -
# mcp tool not working
#
# ## poss sol
# fall back to tools
